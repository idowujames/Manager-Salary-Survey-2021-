# %%
# import necessary modules
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt


from IPython.display import display

# %% [markdown]
# ### Load the data & preview the data

# %%
data = pd.read_csv('../data/raw/Copy of Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv')

# %%
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28061 entries, 0 to 28060
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28061 non-null  object
#  1   How old are you?                                                                                                                                                                                                                      28061 non-null  object
#  2   What industry do you work in?                                                                                                                                                                                                         27987 non-null  object
#  3   Job title                                                                                                                                                                                                                             28060 non-null  object
#  4   If your job title needs additional context, please clarify here:                                                                                                                                                                      7262 non-null   object
#  5   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  28061 non-null  object
#  6   How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                        20766 non-null  float64
#  7   Please indicate the currency                                                                                                                                                                                                          28061 non-null  object
#  8   If "Other," please indicate the currency here:                                                                                                                                                                                        205 non-null    object
#  9   If your income needs additional context, please provide it here:                                                                                                                                                                      3042 non-null   object
#  10  What country do you work in?                                                                                                                                                                                                          28061 non-null  object
#  11  If you're in the U.S., what state do you work in?                                                                                                                                                                                     23039 non-null  object
#  12  What city do you work in?                                                                                                                                                                                                             27979 non-null  object
#  13  How many years of professional work experience do you have overall?                                                                                                                                                                   28061 non-null  object
#  14  How many years of professional work experience do you have in your field?                                                                                                                                                             28061 non-null  object
#  15  What is your highest level of education completed?                                                                                                                                                                                    27839 non-null  object
#  16  What is your gender?                                                                                                                                                                                                                  27890 non-null  object
#  17  What is your race? (Choose all that apply.)                                                                                                                                                                                           27884 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 3.9+ MB
# None
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                             55,000
# 1                                             54,600
# 2                                             34,000
# 3                                             62,000
# 4                                             60,000
#
#    How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                0.0
# 1                                             4000.0
# 2                                                NaN
# 3                                             3000.0
# 4                                             7000.0
#
#   Please indicate the currency  \
# 0                          USD
# 1                          GBP
# 2                          USD
# 3                          USD
# 4                          USD
#
#   If "Other," please indicate the currency here:   \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   If your income needs additional context, please provide it here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What country do you work in?  \
# 0                United States
# 1               United Kingdom
# 2                           US
# 3                          USA
# 4                           US
#
#   If you're in the U.S., what state do you work in? What city do you work in?  \
# 0                                     Massachusetts                    Boston
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
#
#   How many years of professional work experience do you have overall?  \
# 0                                          5-7 years
# 1                                       8 - 10 years
# 2                                        2 - 4 years
# 3                                       8 - 10 years
# 4                                       8 - 10 years
#
#   How many years of professional work experience do you have in your field?  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
#
#   What is your highest level of education completed? What is your gender?  \
# 0                                    Master's degree                Woman
# 1                                     College degree           Non-binary
# 2                                     College degree                Woman
# 3                                     College degree                Woman
# 4                                     College degree                Woman
#
#   What is your race? (Choose all that apply.)
# 0                                       White
# 1                                       White
# 2                                       White
# 3                                       White
# 4                                       White

# %% [markdown]
# ### Cleaning data:
# - standardize column names
# - Remove unnecessary columns
# - convert columns to the appropriate data type
# - handle missing values

# %%
# Make a copy of the original data
df = data.copy()

# %%
df.columns
# Out:
# Index(['Timestamp', 'How old are you?', 'What industry do you work in?',
#        'Job title',
#        'If your job title needs additional context, please clarify here:',
#        'What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)',
#        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#        'Please indicate the currency',
#        'If "Other," please indicate the currency here: ',
#        'If your income needs additional context, please provide it here:',
#        'What country do you work in?',
#        'If you're in the U.S., what state do you work in?',
#        'What city do you work in?',
#        'How many years of professional work experience do you have overall?',
#        'How many years of professional work experience do you have in your field?',
#        'What is your highest level of education completed?',
#        'What is your gender?', 'What is your race? (Choose all that apply.)'],
#       dtype='object')

# %% [markdown]
# **Standardize column names**

# %%
column_names = {
    'Timestamp': 'timestamp',
    'How old are you?': 'age_range',
    'What industry do you work in?': 'industry',
    'Job title': 'job_title',
    'If your job title needs additional context, please clarify here:': 'job_title_context',
    "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)":'salary(annualized)',
    'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.': 'additional_compensation',
    'Please indicate the currency':'currency',
    'If "Other," please indicate the currency here: ': 'other_currency',
    'If your income needs additional context, please provide it here:': 'income_context',
    'What country do you work in?': 'country',
    "If you're in the U.S., what state do you work in?":'us_state',
    'What city do you work in?': 'us_city',
    'How many years of professional work experience do you have overall?': 'years_of_experience',
    'How many years of professional work experience do you have in your field?': 'years_of_experience_in_field',
    'What is your highest level of education completed?': 'level_of_education',
    'What is your gender?': 'gender',
    'What is your race? (Choose all that apply.)': 'race'
}
df.columns = df.columns.map(column_names)

# %%
df.head()
# Out:
#             timestamp age_range                       industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   job_title job_title_context  \
# 0        Research and Instruction Librarian               NaN
# 1  Change & Internal Communications Manager               NaN
# 2                      Marketing Specialist               NaN
# 3                           Program Manager               NaN
# 4                        Accounting Manager               NaN
#
#   salary(annualized)  additional_compensation currency other_currency  \
# 0             55,000                      0.0      USD            NaN
# 1             54,600                   4000.0      GBP            NaN
# 2             34,000                      NaN      USD            NaN
# 3             62,000                   3000.0      USD            NaN
# 4             60,000                   7000.0      USD            NaN
#
#   income_context         country        us_state      us_city  \
# 0            NaN   United States   Massachusetts       Boston
# 1            NaN  United Kingdom             NaN    Cambridge
# 2            NaN              US       Tennessee  Chattanooga
# 3            NaN             USA       Wisconsin    Milwaukee
# 4            NaN              US  South Carolina   Greenville
#
#   years_of_experience years_of_experience_in_field level_of_education  \
# 0           5-7 years                    5-7 years    Master's degree
# 1        8 - 10 years                    5-7 years     College degree
# 2         2 - 4 years                  2 - 4 years     College degree
# 3        8 - 10 years                    5-7 years     College degree
# 4        8 - 10 years                    5-7 years     College degree
#
#        gender   race
# 0       Woman  White
# 1  Non-binary  White
# 2       Woman  White
# 3       Woman  White
# 4       Woman  White

# %% [markdown]
# **Dropping Unnecessary Columns Or Columns with High Missing Values**

# %%
# drop columns with high missing values
(df.isnull().mean() *100).sort_values(ascending=False)
# Out:
# other_currency                  99.269449
# income_context                  89.159331
# job_title_context               74.120666
# additional_compensation         25.996935
# us_state                        17.896725
# level_of_education               0.791134
# race                             0.630769
# gender                           0.609387
# us_city                          0.292221
# industry                         0.263711
# job_title                        0.003564
# timestamp                        0.000000
# age_range                        0.000000
# salary(annualized)               0.000000
# currency                         0.000000
# country                          0.000000
# years_of_experience              0.000000
# years_of_experience_in_field     0.000000
# dtype: float64

# %% [markdown]
# 'income_context', 'other_currency', 'job_title_context' all have more than 70% missing values, so we can drop them. But before doing so, let's check if there are any meaningful information in these columns.

# %%
print('Number of Non-null values in the Other_currency Column: ',len(df[~df['other_currency'].isnull()]))
print('Number of unique values in the Other_currency Column: ',df[~df['other_currency'].isnull()]['other_currency'].nunique())
df[~df['other_currency'].isnull()].iloc[:,:10].sample(20)
# Out:
# Number of Non-null values in the Other_currency Column:  205
# Number of unique values in the Other_currency Column:  121
#                 timestamp age_range  \
# 26727  8/26/2021 15:51:01     35-44
# 26531   7/6/2021 18:49:41     25-34
# 766    4/27/2021 11:14:39     25-34
# 752    4/27/2021 11:14:29     45-54
# 11760   4/28/2021 4:46:46     35-44
# 4971   4/27/2021 12:53:00     35-44
# 18930   4/29/2021 5:20:01     25-34
# 7739   4/27/2021 15:09:39     45-54
# 28054  7/12/2024 18:24:48     25-34
# 9981   4/27/2021 19:33:22     55-64
# 20097  4/29/2021 12:44:46     25-34
# 26343   5/26/2021 6:48:44     35-44
# 27630   1/24/2022 0:18:39     25-34
# 27834  6/15/2022 10:10:04     35-44
# 14331  4/28/2021 14:25:40     45-54
# 19323   4/29/2021 8:59:21     35-44
# 6969   4/27/2021 14:18:47     25-34
# 4264   4/27/2021 12:29:22     25-34
# 10948  4/27/2021 22:50:41     35-44
# 8650   4/27/2021 16:25:55     45-54
#
#                                         industry  \
# 26727               Education (Higher Education)
# 26531                                 Nonprofits
# 766                            Recruitment or HR
# 752    Public Library (technically City Govt.?)
# 11760              Education (Primary/Secondary)
# 4971                Engineering or Manufacturing
# 18930                          Computing or Tech
# 7739                                 Health care
# 28054              Accounting, Banking & Finance
# 9981                     Agriculture or Forestry
# 20097                          Computing or Tech
# 26343               Engineering or Manufacturing
# 27630                          Computing or Tech
# 27834                          Computing or Tech
# 14331                                  Military
# 19323                     Business or Consulting
# 6969                           Computing or Tech
# 4264                                         Law
# 10948              Accounting, Banking & Finance
# 8650                           Computing or Tech
#
#                                                job_title  \
# 26727                                       Receptionist
# 26531                   Districtwide Program Coordinator
# 766                   Lead Payroll & Benefits Specialist
# 752                             Administrative Librarian
# 11760                                        ESL Teacher
# 4971                           Compliance Senior Analyst
# 18930                                        GIS Analyst
# 7739                          Board certified physician
# 28054                                  Financial Analyst
# 9981                                Executive Assistant
# 20097                                         Consultant
# 26343                                 Personal Assistant
# 27630                           Senior Software Engineer
# 27834  Executive Assistant (Office of President and C...
# 14331                                          San Diego
# 19323                                             Editor
# 6969                                  Software Developer
# 4264                                  Associate Attorney
# 10948                           Senior Software Engineer
# 8650                                           Developer
#
#                                        job_title_context salary(annualized)  \
# 26727                                       Receptionist              40000
# 26531                                                NaN              47000
# 766                                                  NaN             64,000
# 752    I run a branch library and am responsible for ...             76,302
# 11760                                                NaN            250,000
# 4971                                                 NaN            534,300
# 18930                                                NaN             38,760
# 7739                 Patient care, teaching and research            145,000
# 28054                                                NaN             300000
# 9981                                                 NaN             91,800
# 20097                      Cyber security, Risk Advisory            750,000
# 26343                                                NaN              46980
# 27630                                                NaN            3000000
# 27834                                                NaN              91000
# 14331                                            Officer            125,000
# 19323                                                NaN            600,000
# 6969                                                 NaN            288,000
# 4264                                                 NaN             62,400
# 10948                                                NaN            226,800
# 8650                               ERP system programmer            240,000
#
#        additional_compensation currency  \
# 26727                      0.0      CAD
# 26531                      NaN      USD
# 766                     6400.0      USD
# 752                        0.0      USD
# 11760                      NaN    Other
# 4971                   63800.0    Other
# 18930                   4200.0    Other
# 7739                       0.0    Other
# 28054                      NaN    Other
# 9981                       0.0    Other
# 20097                 100000.0    Other
# 26343                   7830.0    Other
# 27630                      NaN    Other
# 27834                   2000.0    Other
# 14331                      0.0      USD
# 19323                  74000.0    Other
# 6969                     500.0    Other
# 4264                    1500.0    Other
# 10948                      0.0    Other
# 8650                   12000.0    Other
#
#                                           other_currency  \
# 26727                                           Canadian
# 26531                                              47000
# 766    My bonus is based on performance up to 10% of ...
# 752                                           $76,302.34
# 11760                                          China RMB
# 4971                                       Mexican pesos
# 18930                                                 RM
# 7739                                  PLN (Polish zloty)
# 28054                                                INR
# 9981                                                 AUD
# 20097                                                INR
# 26343                                                SGD
# 27630                                                INR
# 27834                                  Singapore Dollara
# 14331  Many non-salary benefits - travel, free health...
# 19323                                   Philippine Pesos
# 6969                                                 ZAR
# 4264                                                 TTD
# 10948                                                BRL
# 8650                                             ILS/NIS
#
#                                           income_context
# 26727                                                NaN
# 26531                                                NaN
# 766                                                  NaN
# 752                                                  NaN
# 11760  I'm a white, native English speaker from Ameri...
# 4971                                                 NaN
# 18930                                                NaN
# 7739   around 54 hours per week, responsible for own ...
# 28054                                                NaN
# 9981                                                 NaN
# 20097                                                NaN
# 26343                                                NaN
# 27630                                                NaN
# 27834                                                NaN
# 14331        You are in a contract and can’t just quit.
# 19323                                                NaN
# 6969                                                 NaN
# 4264                                                 NaN
# 10948                                                NaN
# 8650                          Plus car and running costs

# %% [markdown]
# There are 121 out of 205 unique values in the 'other_currency' column, with makes it a lot of unique values to deal with and the benefit of dealing with each one is minimal. So the current approach at the moment would be to first drop all the rows in the dataframe that have values in the other_currency column because they can skew the analysis of the data then drop the column itself after.
#
# The other columns with high missing values (income_context, job_title_context) can be dropped without losing any relevant information.

# %%
# Remove rows where 'other_currency' column has non-null values.
df = df[df['other_currency'].isnull()]
df.shape
# Out:
# (27856, 18)

# %%
# Drop unnecessary columns.
df = df.drop(columns=['income_context', 'other_currency', 'job_title_context'],axis=1)

# %%
df.head()
# Out:
#             timestamp age_range                       industry  \
# 0  4/27/2021 11:02:10     25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22     25-34              Computing or Tech
# 2  4/27/2021 11:02:38     25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41     25-34                     Nonprofits
# 4  4/27/2021 11:02:42     25-34  Accounting, Banking & Finance
#
#                                   job_title salary(annualized)  \
# 0        Research and Instruction Librarian             55,000
# 1  Change & Internal Communications Manager             54,600
# 2                      Marketing Specialist             34,000
# 3                           Program Manager             62,000
# 4                        Accounting Manager             60,000
#
#    additional_compensation currency         country        us_state  \
# 0                      0.0      USD   United States   Massachusetts
# 1                   4000.0      GBP  United Kingdom             NaN
# 2                      NaN      USD              US       Tennessee
# 3                   3000.0      USD             USA       Wisconsin
# 4                   7000.0      USD              US  South Carolina
#
#        us_city years_of_experience years_of_experience_in_field  \
# 0       Boston           5-7 years                    5-7 years
# 1    Cambridge        8 - 10 years                    5-7 years
# 2  Chattanooga         2 - 4 years                  2 - 4 years
# 3    Milwaukee        8 - 10 years                    5-7 years
# 4   Greenville        8 - 10 years                    5-7 years
#
#   level_of_education      gender   race
# 0    Master's degree       Woman  White
# 1     College degree  Non-binary  White
# 2     College degree       Woman  White
# 3     College degree       Woman  White
# 4     College degree       Woman  White

# %% [markdown]
# **Cleaning other columns with missing values**

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# additional_compensation         25.969271
# us_state                        17.428920
# level_of_education               0.771827
# race                             0.621051
# gender                           0.610281
# us_city                          0.294371
# industry                         0.258472
# job_title                        0.003590
# salary(annualized)               0.000000
# timestamp                        0.000000
# age_range                        0.000000
# currency                         0.000000
# country                          0.000000
# years_of_experience              0.000000
# years_of_experience_in_field     0.000000
# dtype: float64

# %% [markdown]
# - Additional Compensation Column

# %%
# fill missing values in 'additional_compensation' column with 0
df['additional_compensation'] = df['additional_compensation'].fillna(0)

# %% [markdown]
# - State(US) Column

# %%
# Viewing the pattern of the state(US) column to see if United States has have corresponding states and 
# non United States entries have null values.
df.iloc[:,6:9]
# Out:
#       currency         country        us_state
# 0          USD   United States   Massachusetts
# 1          GBP  United Kingdom             NaN
# 2          USD              US       Tennessee
# 3          USD             USA       Wisconsin
# 4          USD              US  South Carolina
# ...        ...             ...             ...
# 28056      CAD          Canada             NaN
# 28057      USD  United States         Missouri
# 28058      USD             USA         Georgia
# 28059      USD         Myanmar        Colorado
# 28060      USD           Burma             NaN
#
# [27856 rows x 3 columns]

# %%
# View rows with missing values in 'State(US)' column to confirm the pattern.
df[df['us_state'].isnull()].iloc[:,6:10]
# Out:
#       currency          country us_state     us_city
# 1          GBP   United Kingdom      NaN   Cambridge
# 10         USD    United States      NaN  Boston, MA
# 14         CAD           Canada      NaN      Remote
# 15         GBP  United Kingdom       NaN     Lincoln
# 21         USD    United States      NaN     Atlanta
# ...        ...              ...      ...         ...
# 28050      EUR            Spain      NaN   Barcelona
# 28053      CAD           Taiwan      NaN      Taipei
# 28055      CAD           Canada      NaN     Toronto
# 28056      CAD           Canada      NaN   Kitchener
# 28060      USD            Burma      NaN      Yangon
#
# [4855 rows x 4 columns]

# %% [markdown]
# It appears that there are some rows where the 'country' column is 'United States' but the 'State(US)' column is missing.
#
# Since there are multiple entries where the in the country column United States is written in many different ways, we will convert all entries to 'United States' to make it consistent first before dealing with the missing state entries.

# %%
df['country'].unique()
# Out:
# array(['United States', 'United Kingdom', 'US', 'USA', 'Canada',
#        'United Kingdom ', 'usa', 'UK', 'Scotland ', 'U.S.',
#        'United States ', 'The Netherlands', 'Australia ', 'Spain', 'us',
#        'Usa', 'England', 'finland', 'United States of America', 'France',
#        'United states', 'Scotland', 'USA ', 'United states ', 'Germany',
#        'UK ', 'united states', 'Ireland', 'Australia', 'Uk',
#        'United States of America ', 'U.S. ', 'canada', 'Canada ', 'U.S>',
#        'ISA', 'Great Britain ', 'US ', 'United State', 'U.S.A', 'Denmark',
#        'U.S.A.', 'America', 'Netherlands', 'netherlands', 'England ',
#        'united states of america', 'Ireland ', 'Switzerland',
#        'Netherlands ', 'Bermuda', 'Us', 'The United States',
#        'United State of America', 'Germany ', 'Mexico ', 'United Stated',
#        'South Africa ', 'Belgium', 'Northern Ireland', 'u.s.',
#        'South Africa', 'UNITED STATES', 'united States', 'Sweden',
#        'Hong Kong', 'Sri lanka', 'Contracts', 'USA-- Virgin Islands',
#        'United Statws', 'England/UK', 'U.S',
#        "We don't get raises, we get quarterly bonuses, but they periodically asses income in the area you work, so I got a raise because a 3rd party assessment showed I was paid too little for the area we were located",
#        'Unites States ', 'Usa ', 'U.S.A. ', 'England, UK.', 'Greece',
#        'Japan', 'U. S. ', 'Britain ', 'United Sates', 'Japan ', 'Austria',
#        'Canada, Ottawa, ontario', 'Global', 'Sweden ',
#        'United States of American ', 'FRANCE', 'Uniited States',
#        'United Kingdom (England)',
#        'Worldwide (based in US but short term trips aroudn the world)',
#        'CANADA ', 'Canadw', 'Luxembourg', 'United Sates of America',
#        'ireland',
#        'United States (I work from home and my clients are all over the US/Canada/PR',
#        'CANADA', 'Unted States', 'germany', 'United Statesp',
#        'United Stattes', 'United Statea', 'United Kingdom.', 'Mexico',
#        'New Zealand', 'Unites States', 'United Statees', 'United kingdom',
#        'Cayman Islands', 'UNited States', 'Can',
#        'I am located in Canada but I work for a company in the US',
#        'United kingdom ', 'Uniyed states', 'Uniyes States',
#        'United States of Americas', 'U.A.', 'Latvia', 'Finland', 'U. S.',
#        'Puerto Rico', 'US of A', 'Rwanda', 'United States of america ',
#        'United Arab Emirates ', 'Spain ', 'U.K. ', 'Romania', 'U.SA',
#        'United Kindom', 'United Status', 'New Zealand ',
#        'Currently finance', ' U.S.', 'Serbia', 'Russia ', 'UXZ',
#        'England, UK', 'Canda', 'Puerto Rico ', 'Canada and USA',
#        'Catalonia', '$2,175.84/year is deducted for benefits', 'uk',
#        'France ', 'Italy (South)', 'Jersey, Channel islands', 'Uk ',
#        'Virginia', 'Afghanistan', 'U.s.', 'Great Britain', 'U.s.a.',
#        'USS', 'Uniteed States', 'New Zealand Aotearoa', 'U.K.',
#        'Hartford', 'Japan, US Gov position', 'Csnada', 'United Stares',
#        'New zealand', 'I.S.', 'UK (Northern Ireland)',
#        'UK for U.S. company', ' US', 'Unites states ', 'NZ', 'Us ',
#        'Hong Kong ', 'Canad', 'Unite States', 'australia', 'The US',
#        'China', 'united states ', 'The Netherlands ', 'Cambodia',
#        'United states of America ', 'Vietnam', 'Remote', 'India',
#        'Bangladesh', 'Israel', 'Lithuania', 'Eritrea',
#        'For the United States government, but posted overseas', 'IS',
#        'Switzerland ', 'United Kingdomk', 'Italy', ' New Zealand', 'Cuba',
#        'Slovenia', 'Australi', "Cote d'Ivoire", 'united kingdom',
#        'From Romania, but for an US based company', 'Somalia',
#        'Wales (United Kingdom)', 'England, Gb', 'Norway', 'UnitedStates',
#        'spain', 'Danmark', 'U.K. (northern England)', 'U.K', 'Malaysia',
#        'NL', 'the Netherlands', 'Nederland', 'Slovakia',
#        'United States of america', 'Portugal ', 'England, United Kingdom',
#        'Sierra Leone', 'Englang', 'United statew', 'UAE', 'Belgium ',
#        'Singapore',
#        'bonus based on meeting yearly goals set w/ my supervisor',
#        'International ', 'The Bahamas ', 'Wales',
#        "I earn commission on sales. If I meet quota, I'm guaranteed another 16k min. Last year i earned an additional 27k. It's not uncommon for people in my space to earn 100k+ after commission. ",
#        'Costa Rica', ' United States', 'United Statues', 'Argentina',
#        'Untied States',
#        'USA (company is based in a US territory, I work remote)', 'Chile',
#        'denmark', 'UK (England)', 'UK, remote', 'Scotland, UK', 'USAB',
#        'Unitied States', 'Qatar', 'United Sttes', 'Hungary',
#        'Remote (philippines)', 'Unites kingdom ', 'South africa',
#        'Portugal', 'united stated', 'United States Of America', 'Nigeria',
#        'Panamá', 'Northern Ireland ', 'england', 'SWITZERLAND', 'Brazil',
#        'Austria, but I work remotely for a Dutch/British company',
#        'I was brought in on this salary to help with the EHR and very quickly was promoted to current position but compensation was not altered. ',
#        'Uniter Statez', 'U. S ', 'Congo', 'United states of America',
#        'Uruguay', 'USA tomorrow ', 'United Stateds',
#        'n/a (remote from wherever I want)', 'singapore', 'Pakistan',
#        'US govt employee overseas, country withheld', 'usa ', 'Malaysia ',
#        'Uganda', 'Philippines', 'Poland', 'Malta', 'Bulgaria', 'Estonia',
#        'Morocco', 'new zealand', 'Africa', 'Ecuador', 'Zimbabwe', 'Ghana',
#        'San Francisco', 'Usat', '🇺🇸 ', 'Luxemburg', 'Unitef Stated', 'UA',
#        'Wales, UK', 'United Stares ', 'Croatia ',
#        'England, United Kingdom ', 'United STates', 'USaa', 'uSA',
#        'South Korea ', 'The netherlands', 'Ukraine ', 'america',
#        'switzerland', 'United States- Puerto Rico',
#        'From New Zealand but on projects across APAC', 'Y', 'United y',
#        'Thailand', 'Wales (UK)', 'Isle of Man',
#        'Northern Ireland, United Kingdom', 'europe', 'California ',
#        'UK, but for globally fully remote company', 'Australian ',
#        'Jamaica', 'uS', 'USD', 'the netherlands',
#        "USA, but for foreign gov't", 'japan', 'Kenya', 'Jordan',
#        'United Statss', 'United states of america', 'UsA',
#        'I work for a UAE-based organization, though I am personally in the US.',
#        'United  States', 'france', 'Aotearoa New Zealand', 'Policy',
#        'Cyprus', 'hong konh', 'United States is America', 'Liechtenstein',
#        'Company in Germany. I work from Pakistan.', 'Canadá', 'ENGLAND',
#        'United States of American', 'U.S.A ', 'Colombia',
#        'Bosnia and Herzegovina', 'Nigeria ', 'London', 'Saudi Arabia',
#        'LOUTRELAND', 'philippines', 'Taiwan', 'Myanmar', 'Burma'],
#       dtype=object)

# %% [markdown]
# Starting with USA, we can see it was entered in many ways. We will convert them all to 'United States'.

# %% [markdown]
# - Convert all USA entries in 'country' column to 'United States'.

# %%
# First make all the entries in 'country' column lowercase.
df['country'] = df['country'].str.lower().str.strip()

# %%
# show all unique country entries that start with the letter 'u'
df[df['country'].str.startswith('u')]['country'].unique()
# Out:
# array(['united states', 'united kingdom', 'us', 'usa', 'uk', 'u.s.',
#        'united states of america', 'u.s>', 'united state', 'u.s.a',
#        'u.s.a.', 'united state of america', 'united stated',
#        'usa-- virgin islands', 'united statws', 'u.s', 'unites states',
#        'u. s.', 'united sates', 'united states of american',
#        'uniited states', 'united kingdom (england)',
#        'united sates of america',
#        'united states (i work from home and my clients are all over the us/canada/pr',
#        'unted states', 'united statesp', 'united stattes',
#        'united statea', 'united kingdom.', 'united statees',
#        'uniyed states', 'uniyes states', 'united states of americas',
#        'u.a.', 'us of a', 'united arab emirates', 'u.k.', 'u.sa',
#        'united kindom', 'united status', 'uxz', 'uss', 'uniteed states',
#        'united stares', 'uk (northern ireland)', 'uk for u.s. company',
#        'unite states', 'united kingdomk', 'unitedstates',
#        'u.k. (northern england)', 'u.k', 'united statew', 'uae',
#        'united statues', 'untied states',
#        'usa (company is based in a us territory, i work remote)',
#        'uk (england)', 'uk, remote', 'usab', 'unitied states',
#        'united sttes', 'unites kingdom', 'uniter statez', 'u. s',
#        'uruguay', 'usa tomorrow', 'united stateds',
#        'us govt employee overseas, country withheld', 'uganda', 'usat',
#        'unitef stated', 'ua', 'usaa', 'ukraine',
#        'united states- puerto rico', 'united y',
#        'uk, but for globally fully remote company', 'usd',
#        "usa, but for foreign gov't", 'united statss', 'united  states',
#        'united states is america'], dtype=object)

# %%
# Get all the usa varitions into list
usa_list = ['united states', 'us', 'usa', 'u.s.',
       'united states of america', 'u.s>', 'united state', 'u.s.a',
       'u.s.a.', 'united state of america', 'united stated',
       'usa-- virgin islands', 'united statws', 'u.s', 'unites states',
       'u. s.', 'united sates', 'united states of american',
       'uniited states', 'united sates of america',
       'united states (i work from home and my clients are all over the us/canada/pr',
       'unted states', 'united statesp', 'united stattes',
       'united statea', 'united statees',
       'uniyed states', 'uniyes states', 'united states of americas',
       'u.a.', 'us of a', 'u.sa',
       'united status', 'uniteed states',
       'united stares', 'unite states', 'unitedstates',
       'united statew', 'united statues', 'untied states',
       'usa (company is based in a us territory, i work remote)',
       'usab', 'unitied states',
       'united sttes', 'uniter statez', 'u. s',
       'usa tomorrow', 'united stateds',
       'usat', 'unitef stated', 'ua', 'usaa',
       'united y', 'united statss', 'united  states',
       'united states is america','america','isa','the united states',
       'san francisco', '🇺🇸','california','the us']

# replace all USA entries in 'country' column with 'United States' using the list usa_list
df['country'] = df['country'].apply(lambda x: 'united states' if x in usa_list else x)

# %%
df['country'].unique()
# Out:
# array(['united states', 'united kingdom', 'canada', 'uk', 'scotland',
#        'the netherlands', 'australia', 'spain', 'england', 'finland',
#        'france', 'germany', 'ireland', 'great britain', 'denmark',
#        'netherlands', 'switzerland', 'bermuda', 'mexico', 'south africa',
#        'belgium', 'northern ireland', 'sweden', 'hong kong', 'sri lanka',
#        'contracts', 'england/uk',
#        "we don't get raises, we get quarterly bonuses, but they periodically asses income in the area you work, so i got a raise because a 3rd party assessment showed i was paid too little for the area we were located",
#        'england, uk.', 'greece', 'japan', 'britain', 'austria',
#        'canada, ottawa, ontario', 'global', 'united kingdom (england)',
#        'worldwide (based in us but short term trips aroudn the world)',
#        'canadw', 'luxembourg', 'united kingdom.', 'new zealand',
#        'cayman islands', 'can',
#        'i am located in canada but i work for a company in the us',
#        'latvia', 'puerto rico', 'rwanda', 'united arab emirates', 'u.k.',
#        'romania', 'united kindom', 'currently finance', 'serbia',
#        'russia', 'uxz', 'england, uk', 'canda', 'canada and usa',
#        'catalonia', '$2,175.84/year is deducted for benefits',
#        'italy (south)', 'jersey, channel islands', 'virginia',
#        'afghanistan', 'uss', 'new zealand aotearoa', 'hartford',
#        'japan, us gov position', 'csnada', 'i.s.',
#        'uk (northern ireland)', 'uk for u.s. company', 'nz', 'canad',
#        'china', 'cambodia', 'vietnam', 'remote', 'india', 'bangladesh',
#        'israel', 'lithuania', 'eritrea',
#        'for the united states government, but posted overseas', 'is',
#        'united kingdomk', 'italy', 'cuba', 'slovenia', 'australi',
#        "cote d'ivoire", 'from romania, but for an us based company',
#        'somalia', 'wales (united kingdom)', 'england, gb', 'norway',
#        'danmark', 'u.k. (northern england)', 'u.k', 'malaysia', 'nl',
#        'nederland', 'slovakia', 'portugal', 'england, united kingdom',
#        'sierra leone', 'englang', 'uae', 'singapore',
#        'bonus based on meeting yearly goals set w/ my supervisor',
#        'international', 'the bahamas', 'wales',
#        "i earn commission on sales. if i meet quota, i'm guaranteed another 16k min. last year i earned an additional 27k. it's not uncommon for people in my space to earn 100k+ after commission.",
#        'costa rica', 'argentina', 'chile', 'uk (england)', 'uk, remote',
#        'scotland, uk', 'qatar', 'hungary', 'remote (philippines)',
#        'unites kingdom', 'nigeria', 'panamá', 'brazil',
#        'austria, but i work remotely for a dutch/british company',
#        'i was brought in on this salary to help with the ehr and very quickly was promoted to current position but compensation was not altered.',
#        'congo', 'uruguay', 'n/a (remote from wherever i want)',
#        'pakistan', 'us govt employee overseas, country withheld',
#        'uganda', 'philippines', 'poland', 'malta', 'bulgaria', 'estonia',
#        'morocco', 'africa', 'ecuador', 'zimbabwe', 'ghana', 'luxemburg',
#        'wales, uk', 'croatia', 'south korea', 'ukraine',
#        'united states- puerto rico',
#        'from new zealand but on projects across apac', 'y', 'thailand',
#        'wales (uk)', 'isle of man', 'northern ireland, united kingdom',
#        'europe', 'uk, but for globally fully remote company',
#        'australian', 'jamaica', 'usd', "usa, but for foreign gov't",
#        'kenya', 'jordan',
#        'i work for a uae-based organization, though i am personally in the us.',
#        'aotearoa new zealand', 'policy', 'cyprus', 'hong konh',
#        'liechtenstein', 'company in germany. i work from pakistan.',
#        'canadá', 'colombia', 'bosnia and herzegovina', 'london',
#        'saudi arabia', 'loutreland', 'taiwan', 'myanmar', 'burma'],
#       dtype=object)

# %%
# Get all the uk varitions into list
uk_list = ['uk', 'united kingdom (england)', 'united kingdom'
       'united kingdom.', 'u.k.', 'united kindom',
       'uk (northern ireland)', 'uk for u.s. company',
       'united kingdomk', 'u.k. (northern england)', 'u.k',
       'uk (england)', 'uk, remote', 'unites kingdom',
       'uk, but for globally fully remote company','england','england/uk',
       'england, uk.','britain','england, uk','wales (united kingdom)', 'england, gb',
       'england, united kingdom','englang','scotland, uk','wales, uk', 'northern ireland',
       'wales (uk)','northern ireland, united kingdom','london','great britain']

# replace all USA entries in 'country' column with 'United States' using the list usa_list
df['country'] = df['country'].apply(lambda x: 'united kingdom' if x in uk_list else x)

# %%
# Get all the canada varitions into list
canada_list = ['canada', 'canada, ottawa, ontario', 'canadw',
       'can', 'canda', 'canada and usa', 'canad',
       'canadá','csnada']

# replace all USA entries in 'country' column with 'United States' using the list usa_list
df['country'] = df['country'].apply(lambda x: 'canada' if x in canada_list else x)

# %% [markdown]
# Since some entries in the 'country' column have sentences rather than country names, we will drop these rows

# %%
# Drop rows where 'country' column has more than 3 words
df = df[df['country'].str.split().apply(len) <= 3]

# %% [markdown]
# Getting the count of each country in the dataframe

# %%
value_counts = df['country'].value_counts()
value_counts
# Out:
# country
# united states     23141
# canada             1683
# united kingdom     1544
# australia           377
# germany             195
#                   ...
# saudi arabia          1
# loutreland            1
# taiwan                1
# myanmar               1
# burma                 1
# Name: count, Length: 126, dtype: int64

# %% [markdown]
# Also based on the frequency of the top countries, we will keep only the countries with more than 100 entries, as countries with less than that may not provide meaningful insights in this dataset.

# %%
df = df[df['country'].isin(value_counts[value_counts > 100].index)]

# %% [markdown]
# **Now that we are done cleaning the 'country' column, we can now go back to the state column to fill the missing values.**
#
# Fisrt we will check the rows where the 'country' column is 'United States' but the state column is missing.

# %%
df.query('country == "united states" and us_state.isnull()')
# Out:
#                 timestamp age_range                              industry  \
# 10     4/27/2021 11:03:03     25-34                            Nonprofits
# 21     4/27/2021 11:03:24     35-44                            Nonprofits
# 71     4/27/2021 11:04:39     35-44                 Aerospace contracting
# 132    4/27/2021 11:05:46     35-44                     Computing or Tech
# 133    4/27/2021 11:05:46     55-64          Education (Higher Education)
# ...                   ...       ...                                   ...
# 25323   5/6/2021 12:39:18     35-44  Government and Public Administration
# 25599    5/7/2021 1:18:37     25-34                           Health care
# 26119  5/12/2021 23:53:52     35-44                       Media & Digital
# 26494  6/22/2021 11:47:22     35-44         Education (Primary/Secondary)
# 28006    2/6/2024 9:07:45  under 18                                   NaN
#
#                                      job_title salary(annualized)  \
# 10                              Office Manager             47,500
# 21     Program Coordinator & Assistant Editor              50,000
# 71                           Project engineer             122,000
# 132                            Product Manager            130,000
# 133               career services professional             55,000
# ...                                        ...                ...
# 25323                    Senior Fiscal Analyst             130000
# 25599                      Physician Assistant             135000
# 26119                                   Editor              45000
# 26494                      High School Teacher              56650
# 28006                                       vv                 76
#
#        additional_compensation currency        country us_state  \
# 10                         0.0      USD  united states      NaN
# 21                         0.0      USD  united states      NaN
# 71                      3600.0      USD  united states      NaN
# 132                        0.0      USD  united states      NaN
# 133                        0.0      USD  united states      NaN
# ...                        ...      ...            ...      ...
# 25323                  25000.0      USD  united states      NaN
# 25599                      0.0      USD  united states      NaN
# 26119                      0.0      USD  united states      NaN
# 26494                   1000.0      USD  united states      NaN
# 28006                      0.0      USD  united states      NaN
#
#                                     us_city years_of_experience  \
# 10                               Boston, MA           5-7 years
# 21                                  Atlanta           5-7 years
# 71                         Colorado Springs       11 - 20 years
# 132                           Philadelphia        11 - 20 years
# 133                            Indianapolis       21 - 30 years
# ...                                     ...                 ...
# 25323                Prefer not to disclose       11 - 20 years
# 25599                           Springfield         2 - 4 years
# 26119  Fully remote company based out of CA       11 - 20 years
# 26494                          Philadelphia           5-7 years
# 28006                                irving      1 year or less
#
#       years_of_experience_in_field level_of_education gender   race
# 10                       5-7 years     College degree  Woman  White
# 21                     2 - 4 years                PhD  Woman  White
# 71                   11 - 20 years    Master's degree  Woman  White
# 132                  11 - 20 years     College degree    Man  White
# 133                  21 - 30 years    Master's degree  Woman  White
# ...                            ...                ...    ...    ...
# 25323                11 - 20 years    Master's degree  Woman  White
# 25599                  2 - 4 years    Master's degree  Woman  White
# 26119                 8 - 10 years     College degree  Woman  White
# 26494                  2 - 4 years    Master's degree  Woman  White
# 28006               1 year or less                NaN    NaN    NaN
#
# [171 rows x 15 columns]

# %% [markdown]
# - We will first deal with the entries where the 'country' column is 'United States' and the state column is missing and the currency column is 'usd' which verifies that this are actual 'united states' entries. We will fill this with "ND" for "Not Disclosed".
#
# - Finally, we will fill correctly identified non united states entries with "N/A" for "Not Applicable".

# %%
# Fill entries where 'country' column is 'United States' and 'us_state' column is missing with 'ND'
df.loc[
    (df['country'] == "united states") & (df['us_state'].isnull()) & (df['currency'] == "USD"),
    'us_state'
] = "ND"

# %%
# Making sure the remaining missing values are not in 'United States'
df[df['us_state'].isnull()].sample(5)
# Out:
#                 timestamp age_range                              industry  \
# 11898   4/28/2021 6:40:30     35-44           Marketing, Advertising & PR
# 11713   4/28/2021 4:00:59     35-44                     Computing or Tech
# 1734   4/27/2021 11:31:03     35-44  Government and Public Administration
# 26461  6/13/2021 13:09:36     35-44                                Retail
# 22903    5/1/2021 7:13:41     25-34                Transport or Logistics
#
#                    job_title salary(annualized)  additional_compensation  \
# 11898      Head of Marketing             35,000                      0.0
# 11713      Junior Developer              26,500                      0.0
# 1734   Senior Policy Analyst            115,000                      0.0
# 26461           Book shelver              35000                      0.0
# 22903                Planner              27000                      0.0
#
#       currency         country us_state              us_city  \
# 11898      GBP  united kingdom      NaN  Newcastle-upon-Tyne
# 11713      GBP  united kingdom      NaN              Bristol
# 1734       CAD          canada      NaN               Ottawa
# 26461      CAD          canada      NaN              Calgary
# 22903      GBP  united kingdom      NaN          Manchester
#
#       years_of_experience years_of_experience_in_field level_of_education  \
# 11898       11 - 20 years                 8 - 10 years     College degree
# 11713           5-7 years               1 year or less     College degree
# 1734        11 - 20 years                11 - 20 years     College degree
# 26461       11 - 20 years                11 - 20 years     College degree
# 22903       11 - 20 years                  2 - 4 years       Some college
#
#                               gender  \
# 11898                            Man
# 11713                          Woman
# 1734                           Woman
# 26461  Other or prefer not to answer
# 22903                          Woman
#
#                                                     race
# 11898                                              White
# 11713                                              White
# 1734   Another option not listed here or prefer not t...
# 26461                                              White
# 22903                                              White

# %%
# Fill remaining missing values in 'us_state' column with 'N/A'
df['us_state'] = df['us_state'].fillna("N/A")
